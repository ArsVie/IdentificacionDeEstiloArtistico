# %% [markdown]
# # Librerias

# %%
import os
import numpy as np
import matplotlib as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten,Dense
import warnings
import re
warnings.filterwarnings("ignore")
# Out:
# 2025-05-01 14:36:23.696676: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Preprocesamiento

# %%
datagen = ImageDataGenerator(rescale=1./255,validation_split=0.95)

# %%
train_generator = datagen.flow_from_directory(
    directory='./data/pinturas3',
    target_size=(128, 128),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)
val_generator = datagen.flow_from_directory(
    directory='./data/pinturas3',
    target_size=(128, 128),
    batch_size=32,
    class_mode='categorical',
    subset='validation'         # Use validation subset
)
# Out:
# Found 2131 images belonging to 13 classes.

# %%
print(train_generator.class_indices)
# Out:
# {'Academic_Art': 0, 'Art_Nouveau': 1, 'Baroque': 2, 'Expressionism': 3, 'Japanese_Art': 4, 'Neoclassicism': 5, 'Primitivism': 6, 'Realism': 7, 'Renaissance': 8, 'Rococo': 9, 'Romanticism': 10, 'Symbolism': 11, 'Western_Medieval': 12}

# %% [markdown]
# # Modelo

# %%
model = Sequential([
    tf.keras.layers.Rescaling(1./255, input_shape=(128, 128, 3)),
    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(13, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=10,
    validation_data=val_generator,
    validation_steps=val_generator.samples // val_generator.batch_size
)
# Out:
# Epoch 1/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 588s 9s/step - accuracy: 0.1899 - loss: 2.6638 - val_accuracy: 0.2001 - val_loss: 2.6680
# Epoch 2/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 543s 8s/step - accuracy: 0.4375 - loss: 1.8470 - val_accuracy: 0.1983 - val_loss: 2.7033
# Epoch 3/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 648s 10s/step - accuracy: 0.4178 - loss: 1.7779 - val_accuracy: 0.2085 - val_loss: 2.8093
# Epoch 4/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 597s 9s/step - accuracy: 0.5625 - loss: 1.4242 - val_accuracy: 0.2076 - val_loss: 2.8027
# Epoch 5/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 637s 10s/step - accuracy: 0.5976 - loss: 1.2512 - val_accuracy: 0.1846 - val_loss: 3.6524
# Epoch 6/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 581s 9s/step - accuracy: 0.6250 - loss: 1.2470 - val_accuracy: 0.1850 - val_loss: 3.8332
# Epoch 7/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 950s 15s/step - accuracy: 0.7346 - loss: 0.8424 - val_accuracy: 0.2016 - val_loss: 3.6519
# Epoch 8/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 886s 14s/step - accuracy: 0.7188 - loss: 0.9883 - val_accuracy: 0.1916 - val_loss: 3.8536
# Epoch 9/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1080s 16s/step - accuracy: 0.8556 - loss: 0.4761 - val_accuracy: 0.2045 - val_loss: 4.2425
# Epoch 10/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 943s 14s/step - accuracy: 0.8125 - loss: 0.5773 - val_accuracy: 0.2022 - val_loss: 4.3098

# %%
def predict_class(model, image_path):
    img = tf.keras.preprocessing.image.load_img(image_path, target_size=(128, 128))
    img = tf.keras.preprocessing.image.img_to_array(img)
    img = np.expand_dims(img, axis=0) 
    img = 1/255.0  
    predictions = model.predict(img)
    predicted_class = np.argmax(predictions[0])
    return predicted_class

# %%
# Probar el modelo con una imagen
predict_class(model,'')
